# %% [markdown]
# # EXPLORITY DATA ANALYSIS :-

# %% [markdown]
# # DATASET - STUDENT PERFORMANCE :
#
# # 1) Problem statement
# *   This project understands how the student's performance (test scores) is affected by other variables such as Gender,         Ethnicity, Parental level of education, Lunch and Test preparation course.
#
# #  2) Data Collection
# * Dataset Source - https://www.kaggle.com/datasets/spscientist/students-performance-in-exams?datasetId=74977
#   The data consists of 8 column and 1000 rows.
#
# # 3) Dataset Information
# * gender : sex of students -> (Male/female)
# * race/ethnicity : ethnicity of students -> (Group A, B,C, D,E)
# * parental level of education : parents' final education ->(bachelor's degree,some college,master's degree,associate's         degree,high school)
# * lunch : having lunch before test (standard or free/reduced)
# * test preparation course : complete or not complete before test
# * math score
# * reading score
# * writing score

# %% [markdown]
# # EDA Student Performance Indicator

# %%
# import the Important Library
import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings 
warnings.filterwarnings("ignore")

# %%
# Read the Dataset :
df = pd.read_csv("stud.csv")
df.head()
# Out:
#    gender race_ethnicity parental_level_of_education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test_preparation_course  math_score  reading_score  writing_score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
# See the Shape of the Dataset :
df.shape
# Out:
# (1000, 8)

# %% [markdown]
# # CHECK DATA TO PERFORM :-
#
# * Read the Summary of the Dataset
# * Check the Missing Values
# * Check the Duplicates
# * Check Data type
# * Check the Number of Unique Value of Each Columns
# * Check Statistics for the Dataset
# * Check the Various Categories from the Different Categorical Column

# %%
# Read the Summary of the Dataset .
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race_ethnicity               1000 non-null   object
#  2   parental_level_of_education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test_preparation_course      1000 non-null   object
#  5   math_score                   1000 non-null   int64
#  6   reading_score                1000 non-null   int64
#  7   writing_score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
# Check the Missing Values :
df.isnull().sum()
# Out:
# gender                         0
# race_ethnicity                 0
# parental_level_of_education    0
# lunch                          0
# test_preparation_course        0
# math_score                     0
# reading_score                  0
# writing_score                  0
# dtype: int64

# %% [markdown]
# # Insights or Observation
# * There is No Missing Values in the Dataset

# %%
# Check the Duplicates :
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# * There is No Duplicates Present in the Dataset

# %%
# Check the DataType :
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race_ethnicity               1000 non-null   object
#  2   parental_level_of_education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test_preparation_course      1000 non-null   object
#  5   math_score                   1000 non-null   int64
#  6   reading_score                1000 non-null   int64
#  7   writing_score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
# Check the Number of Unique Values in each Columns :
df.nunique()
# Out:
# gender                          2
# race_ethnicity                  5
# parental_level_of_education     6
# lunch                           2
# test_preparation_course         2
# math_score                     81
# reading_score                  72
# writing_score                  77
# dtype: int64

# %%
# Check the Statistics of the Dataset :
df.describe()
# Out:
#        math_score  reading_score  writing_score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %% [markdown]
# # INSIGHTS OR OBSERVATIONS
#
# * From the Above Observed Dataset i Observed that The Mean Between the Student is Close to 66.08 To 69.16
# * All the Standard Deviation are Also Close to the 14.60 to 15.16
# * There is minimum 0 for the Math while Other for they are 10 To 17

# %%
# Explore More About the Data :
df.head()
# Out:
#    gender race_ethnicity parental_level_of_education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test_preparation_course  math_score  reading_score  writing_score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
df.tail()
# Out:
#      gender race_ethnicity parental_level_of_education         lunch  \
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test_preparation_course  math_score  reading_score  writing_score
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86

# %%
# Get out the Categorical Features :
[feature for feature in df.columns if df[feature].dtype== 'O']
# Out:
# ['gender',
#  'race_ethnicity',
#  'parental_level_of_education',
#  'lunch',
#  'test_preparation_course']

# %%
# Segrregate the Numerical & Categorical Features 
categorical_feature = [feature for feature in df.columns if df[feature].dtype == 'O']
numerical_feature = [feature for feature in df.columns if df[feature].dtype != 'O' ]

# %%
categorical_feature
# Out:
# ['gender',
#  'race_ethnicity',
#  'parental_level_of_education',
#  'lunch',
#  'test_preparation_course']

# %%
numerical_feature
# Out:
# ['math_score', 'reading_score', 'writing_score']

# %%
# See the Unique Value in the Features 
df['gender'].value_counts()
# Out:
# female    518
# male      482
# Name: gender, dtype: int64

# %%
df['race_ethnicity'].value_counts()
# Out:
# group C    319
# group D    262
# group B    190
# group E    140
# group A     89
# Name: race_ethnicity, dtype: int64

# %%
## Aggregate the Total Score with Mean  
df['total_score'] = ( df['math_score'] + df['reading_score'] + df['writing_score'])
df['Average'] = df['total_score'] / 3
df.head()
# Out:
#    gender race_ethnicity parental_level_of_education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test_preparation_course  math_score  reading_score  writing_score  \
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
#
#    total_score    Average
# 0          218  72.666667
# 1          247  82.333333
# 2          278  92.666667
# 3          148  49.333333
# ...

# %%
# Explore More With Visualization :
fig,axis = plt.subplots(1,2,figsize=(15,7))
plt.subplot(121)
sns.histplot(data=df,x='Average',bins=30,kde=True,color='g')
plt.subplot(122)
sns.histplot(data=df,x='Average',bins=39,kde=True,hue = 'gender')
# Out:
# <AxesSubplot: xlabel='Average', ylabel='Count'>

# %% [markdown]
# # INSIGHTS :-
#
# * Female Students perform Well as Compare To Male Students

# %%
plt.subplots(1,3,figsize=(25,6))
plt.subplot(131)
sns.histplot(data=df , x = "Average" ,bins=30, kde = True , hue = 'lunch')
plt.subplot(132)
sns.histplot(data=df[df.gender=='female'],x='Average',bins=30,kde=True,hue='lunch')
plt.subplot(133)
sns.histplot(data=df[df.gender=='male'],x='Average',bins=30,kde=True,hue='lunch')
# Out:
# <AxesSubplot: xlabel='Average', ylabel='Count'>

# %% [markdown]
# # Insights
#
# * Standard Lunch Help Students to Get Better Formance
# * Standard Lucnh Help to Well Performed in the Exam Male & Female Both .

# %%
df.head()
# Out:
#    gender race_ethnicity parental_level_of_education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test_preparation_course  math_score  reading_score  writing_score  \
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
#
#    total_score    Average
# 0          218  72.666667
# 1          247  82.333333
# 2          278  92.666667
# 3          148  49.333333
# ...

# %%
plt.subplots(1,3,figsize=(25,6))
plt.subplot(141)
sns.histplot(data=df,x='Average',bins=30,kde=True ,hue='parental_level_of_education')
plt.subplot(142)
sns.histplot(data=df[df.gender =='female'],x="Average",bins=30,kde=True,hue='parental_level_of_education')
plt.subplot(143)
sns.histplot(data=df[df.gender =='male'],x='Average',bins=30,kde=True,hue='parental_level_of_education')
# Out:
# <AxesSubplot: xlabel='Average', ylabel='Count'>

# %% [markdown]
# # INSIGHTS :
#
# * In General The Parentals Education Does Not Effect to Well Perform the Examination
# * In the 2nd Plot there is no effect in the Score of the childrens
# * In the 3rd Plot the Parental Education show the effect in which students perform Well in the Examination .

# %%
# Explore the More Data 
df.head()
# Out:
#    gender race_ethnicity parental_level_of_education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test_preparation_course  math_score  reading_score  writing_score  \
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
#
#    total_score    Average
# 0          218  72.666667
# 1          247  82.333333
# 2          278  92.666667
# 3          148  49.333333
# ...

# %%
plt.subplots(1,3,figsize=(25,6))
plt.subplot(131)
sns.histplot(data=df,x="Average",bins=30,kde=True,hue="test_preparation_course")
plt.subplot(132)
sns.histplot(data=df[df.gender=="female"],x="Average",bins=30,kde=True,hue="test_preparation_course")
plt.subplot(133)
ax = sns.histplot(data=df[df.gender=="male"],x="Average",bins=30,kde=True,hue="test_preparation_course")
plt.show()

# %% [markdown]
# # Insights :
#
# * From the Data observed that Many students who not Completed the Test Prepation Course have less marks in the Test as
#   Compared to the Those student who completed the test prepation course .
#
# * 2nd Plot(Female) tell us many girls who Complete the Test Prepation Well played in the Examination and Score up to 75
#   marks .
#
# * 3rd Plot(Male) Show that a Large Amount of Male is not complete the test Prepation course so their performance is less
#   than As Compare to the Girls who play well in the Exam.and those Male student Complete the Course have Score up to 72
#   Marks which is better performance as compard to those Male who not complete the course

# %%
# Explore more Data :
df.head()
# Out:
#    gender race_ethnicity parental_level_of_education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test_preparation_course  math_score  reading_score  writing_score  \
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
#
#    total_score    Average
# 0          218  72.666667
# 1          247  82.333333
# 2          278  92.666667
# 3          148  49.333333
# ...

# %%
plt.subplots(1,3,figsize=(25,6))
plt.subplot(141)
ax = sns.histplot(data=df,x="Average",bins=30,kde=True,hue="race_ethnicity")
plt.subplot(142)
ax = sns.histplot(data=df[df.gender=="female"],x="Average",bins=30,kde=True,hue="race_ethnicity")
plt.subplot(143)
ax = sns.histplot(data=df[df.gender=="male"],x="Average",bins=30,kde=True,hue="race_ethnicity")
plt.show()

# %% [markdown]
# # Insights :
# * Students of group A and group B tends to perform poorly in exam.
# * Students of group A and group B tends to perform poorly in exam irrespective of whether they are male or female .

# %%
# Now see the Data Correlation between Numerical Feature Using Heatmap Function
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot: >
